# %% [markdown]
# # NYC Geoclient Tool
#
# This notebook contains some live results from running New York City's [Geoclient API](http://developer.cityofnewyork.us/api/geoclient-api).
#
# The NYC Geoclient is a comprehensive REST API endpoint which returns all geographical data about an address, a bin, a borough-block-lot, a street intersection, a blockface, or a known place. It attempts to be comprehensive, pooling together GIS resources from dozens of disparate databases in attempting to return its answer. As a result it returns extremely verbose answers; you can understand the finer points of each of the returned parameters by reading the API's [extensive documentation](https://api.cityofnewyork.us/geoclient/v1/doc).
#
# This notebook is intended to confirm the cross-version compatibility of [my pull request to the Geoclient codebase](https://github.com/talos/nyc-geoclient/pull/3). Run this note in Python 3 and then in Python 2 to confirm cross-version compatibility.

# %%
from api import Geoclient

# %%
help(Geoclient)
# Out:
# Help on class Geoclient in module api:
#
# class Geoclient(__builtin__.object)
#  |  This object's methods provide access to the NYC Geoclient REST API.
#  |  You must have registered an app with the NYC Developer Portal
#  |  (http://developer.cityofnewyork.us/api/geoclient-api-beta), and make sure
#  |  that you check off access to the Geoclient API for the application.  Take
#  |  note of the Application's ID and key.  You will not be able to use the ID
#  |  and key until DoITT approves you -- this could take several days, and you
#  |  will receive an email when this happens.  There isn't any indication of
#  |  your status on the dashboard, but all requests will return a 403 until you
#  |  are approved.
#  |  All methods return a dict, whether or not the geocoding succeeded.  If it
#  |  failed, the dict will have a `message` key with information on why it
#  |  failed.
#  |  :param app_id:
#  |      Your NYC Geoclient application ID.
#  |  :param app_key:
#  |      Your NYC Geoclient application key.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, app_id, app_key)
#  |
#  |  address(self, houseNumber, street, borough)
#  |      Given a valid address, provides blockface-level, property-level, and
#  |      political information.
#  |      :param houseNumber:
#  |          The house number to look up.
#  |      :param street:
#  |          The name of the street to look up.
#  |      :param borough:
#  |          The borough to look within.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :returns: A dict with blockface-level, property-level, and political
#  |          information.
#  |
#  |  address_zip(self, houseNumber, street, zip)
#  |      Like the above address function, except it uses "zip code" instead of borough
#  |      :param houseNumber:
#  |          The house number to look up.
#  |      :param street:
#  |          The name of the street to look up
#  |      :param zip:
#  |          The zip code of the address to look up.
#  |      :returns: A dict with blockface-level, property-level, and political
#  |          information.
#  |
#  |  bbl(self, borough, block, lot)
#  |      Given a valid borough, block, and lot provides property-level
#  |      information.
#  |      :param borough:
#  |          The borough to look within.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :param block:
#  |          The tax block to look up.
#  |      :param lot:
#  |          The tax lot to look up.
#  |      :returns: A dict with property-level information.
#  |
#  |  bin(self, bin)
#  |      Given a valid building identification number (BIN) provides
#  |      property-level information.
#  |      :param bin:
#  |          The BIN to look up.
#  |      :returns: A dict with property-level information.
#  |
#  |  blockface(self, onStreet, crossStreetOne, crossStreetTwo, borough, boroughCrossStreetOne=None, boroughCrossStreetTwo=None, compassDirection=None)
#  |      Given a valid borough, "on street" and cross streets provides
#  |      blockface-level information.
#  |      :param onStreet:
#  |          "On street" (street name of target blockface).
#  |      :param crossStreetOne:
#  |          First cross street of blockface.
#  |      :param crossStreetTwo:
#  |          Second cross street of blockface.
#  |      :param borough:
#  |          The borough to look within.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :param boroughCrossStreetOne:
#  |          (optional) Borough of first cross street. Defaults to value of
#  |          borough parameter if not supplied.
#  |      :param boroughCrossStreetTwo:
#  |          (optional) Borough of second cross street. Defaults to value of
#  |          borough parameter if not supplied.
#  |      :param compassDirection:
#  |          (optional) Used to request information about only one side of the
#  |          street. Valid values are: N, S, E or W.
#  |      :returns: A dict with blockface-level information.
#  |
#  |  intersection(self, crossStreetOne, crossStreetTwo, borough, boroughCrossStreetTwo=None, compassDirection=None)
#  |      Given a valid borough and cross streets returns information for the
#  |      point defined by the two streets.
#  |      :param crossStreetOne:
#  |          First cross street
#  |      :param crossStreetTwo:
#  |          Second cross street
#  |      :param borough:
#  |          Borough of first cross street or of all cross streets if no other
#  |          borough parameter is supplied.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :param boroughCrossStreetTwo:
#  |          (optional) Borough of second cross street. If not supplied, assumed
#  |          to be same as borough parameter.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :param compassDirection:
#  |          (optional) Optional. for most requests. Required for streets that
#  |          intersect more than once. Valid values are: N, S, E or W.
#  |      :returns: A dict with intersection-level information.
#  |
#  |  place(self, name, borough)
#  |      Same as 'Address' above using well-known NYC place name for input.
#  |      :param name:
#  |          Place name of well-known NYC location.
#  |      :param borough:
#  |          Must be 'Bronx', 'Brooklyn', 'Manhattan', 'Queens', or 'Staten
#  |          Island' (case-insensitive).
#  |      :returns: A dict with place-level information.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  BASE_URL = u'https://api.cityofnewyork.us/geoclient/v1/'

# %%
geoclient = Geoclient(app_id='e8641bad', app_key='22c53431c17717ffa7620fa546dd1272')

# %% [markdown]
# `address`, `addresszip`, `bin`, `bbl` all return the same output, just with different input.

# %%
geoclient.address('2900', 'Ocean Avenue', 'Brooklyn')
# Out:
# {u'assemblyDistrict': u'41',
#  u'bbl': u'3074407501',
#  u'bblBoroughCode': u'3',
#  u'bblTaxBlock': u'07440',
#  u'bblTaxLot': u'7501',
#  u'boardOfElectionsPreferredLgc': u'1',
#  u'boePreferredStreetName': u'OCEAN AVENUE',
#  u'boePreferredstreetCode': u'36753001',
#  u'boroughCode1In': u'3',
#  u'buildingIdentificationNumber': u'3204172',
#  u'censusBlock2000': u'3000',
#  u'censusBlock2010': u'3000',
#  u'censusTract1990': u' 592  ',
#  u'censusTract2000': u' 592  ',
#  u'censusTract2010': u' 592  ',
#  u'cityCouncilDistrict': u'48',
#  u'civilCourtDistrict': u'08',
#  u'coincidentSegmentCount': u'1',
#  u'communityDistrict': u'315',
#  u'communityDistrictBoroughCode': u'3',
#  u'communityDistrictNumber': u'15',
#  u'communitySchoolDistrict': u'22',
#  u'condominiumBillingBbl': u'3074407501',
#  u'condominiumFlag': u'C',
#  u'congressionalDistrict': u'09',
#  u'cooperativeIdNumber': u'0000',
#  u'cornerCode': u'SW',
#  u'crossStreetNamesFlagIn': u'E',
#  u'dcpPreferredLgc': u'01',
#  u'dofCondominiumIdentificationNumber': u'0014',
#  u'dotStreetLightContractorArea': u'3',
#  u'dynamicBlock': u'303',
#  u'electionDistrict': u'081',
#  u'fireBattalion': u'43',
#  u'fireCompanyNumber': u'246',
#  u'fireCompanyType': u'E',
#  u'fireDivision': u'08',
#  u'firstBoroughName': u'BROOKLYN',
#  u'firstStreetCode': u'36753001010',
#  u'firstStreetNameNormalized': u'OCEAN AVENUE',
#  u'fromLionNodeId': u'0017059',
#  u'fromPreferredLgcsFirstSetOf5': u'0101',
#  u'genericId': u'0033257',
#  u'geosupportFunctionCode': u'1B',
#  u'geosupportReturnCode': u'00',
#  u'geosupportReturnCode2': u'00',
#  u'gi5DigitStreetCode1': u'67530',
#  u'gi5DigitStreetCode2': u'14830',
#  u'giBoroughCode1': u'3',
#  u'giBoroughCode2': u'3',
#  u'giBuildingIdentificationNumber1': u'3204172',
#  u'giBuildingIdentificationNumber2': u'3204172',
#  u'giDcpPreferredLgc1': u'01',
#  u'giDcpPreferredLgc2': u'01',
#  u'giHighHouseNumber1': u'2900',
#  u'giHighHouseNumber2': u'1930',
#  u'giLowHouseNumber1': u'2900',
#  u'giLowHouseNumber2': u'1930',
#  u'giSideOfStreetIndicator1': u'R',
#  u'giSideOfStreetIndicator2': u'R',
#  u'giStreetCode1': u'36753001',
#  u'giStreetCode2': u'31483001',
#  u'giStreetName1': u'OCEAN AVENUE',
#  u'giStreetName2': u'AVENUE Y',
#  u'healthArea': u'8721',
#  u'healthCenterDistrict': u'37',
#  u'highBblOfThisBuildingsCondominiumUnits': u'3074401088',
#  u'highCrossStreetB5SC1': u'314880',
#  u'highCrossStreetCode1': u'31488001',
#  u'highCrossStreetName1': u'AVENUE Z',
#  u'highHouseNumberOfBlockfaceSortFormat': u'002980000AA',
#  u'houseNumber': u'2900',
#  u'houseNumberIn': u'2900',
#  u'houseNumberSortFormat': u'002900000AA',
#  u'hurricaneEvacuationZone': u'1',
#  u'instructionalRegion': u'BS',
#  u'interimAssistanceEligibilityIndicator': u'I',
#  u'internalLabelXCoordinate': u'0998121',
#  u'internalLabelYCoordinate': u'0154305',
#  u'latitude': 40.59027904122673,
#  u'latitudeInternalLabel': 40.59019685587441,
#  u'legacySegmentId': u'0026242',
#  u'lionBoroughCode': u'3',
#  u'lionBoroughCodeForVanityAddress': u'3',
#  u'lionFaceCode': u'5976',
#  u'lionFaceCodeForVanityAddress': u'5976',
#  u'lionKey': u'3597607080',
#  u'lionKeyForVanityAddress': u'3597607080',
#  u'lionSequenceNumber': u'07080',
#  u'lionSequenceNumberForVanityAddress': u'07080',
#  u'listOf4Lgcs': u'01',
#  u'longitude': -73.94969344311185,
#  u'longitudeInternalLabel': -73.95005715779811,
#  u'lowBblOfThisBuildingsCondominiumUnits': u'3074401001',
#  u'lowCrossStreetB5SC1': u'314830',
#  u'lowCrossStreetB5SC2': u'340650',
#  u'lowCrossStreetCode1': u'31483001',
#  u'lowCrossStreetCode2': u'34065001',
#  u'lowCrossStreetName1': u'AVENUE Y',
#  u'lowCrossStreetName2': u'FIREMANS CORNER SHEEPSHEAD BAY',
#  u'lowHouseNumberOfBlockfaceSortFormat': u'002898000AA',
#  u'lowHouseNumberOfDefiningAddressRange': u'002900000AA',
#  u'nta': u'BK17',
#  u'ntaName': u'Sheepshead Bay-Gerritsen Beach-Manhattan Beach',
#  u'numberOfCrossStreetB5SCsHighAddressEnd': u'1',
#  u'numberOfCrossStreetB5SCsLowAddressEnd': u'2',
#  u'numberOfCrossStreetsHighAddressEnd': u'1',
#  u'numberOfCrossStreetsLowAddressEnd': u'2',
#  u'numberOfEntriesInListOfGeographicIdentifiers': u'0002',
#  u'numberOfExistingStructuresOnLot': u'0001',
#  u'numberOfStreetFrontagesOfLot': u'02',
#  u'physicalId': u'0038421',
#  u'policePatrolBoroughCommand': u'4',
#  u'policePrecinct': u'061',
#  u'returnCode1a': u'00',
#  u'returnCode1e': u'00',
#  u'roadwayType': u'1',
#  u'rpadBuildingClassificationCode': u'R4',
#  u'rpadSelfCheckCodeForBbl': u'1',
#  u'sanbornBoroughCode': u'3',
#  u'sanbornPageNumber': u'005',
#  u'sanbornVolumeNumber': u'18',
#  u'sanitationCollectionSchedulingSectionAndSubsection': u'3D',
#  u'sanitationDistrict': u'315',
#  u'sanitationRecyclingCollectionSchedule': u'ET',
#  u'sanitationRegularCollectionSchedule': u'TF',
#  u'sanitationSnowPriorityCode': u'P',
#  u'segmentAzimuth': u'278',
#  u'segmentIdentifier': u'0026242',
#  u'segmentLengthInFeet': u'00780',
#  u'segmentOrientation': u'S',
#  u'segmentTypeCode': u'U',
#  u'selfCheckCodeOfBillingBbl': u'1',
#  u'sideOfStreetIndicator': u'R',
#  u'sideOfStreetOfVanityAddress': u'R',
#  u'splitLowHouseNumber': u'002898000AA',
#  u'stateSenatorialDistrict': u'22',
#  u'streetName1In': u'OCEAN AVENUE',
#  u'streetStatus': u'2',
#  u'streetWidth': u'70',
#  u'taxMapNumberSectionAndVolume': u'32205',
#  u'toLionNodeId': u'0017053',
#  u'toPreferredLgcsFirstSetOf5': u'01',
#  u'trafficDirection': u'T',
#  u'underlyingStreetCode': u'36753001',
#  u'uspsPreferredCityName': u'BROOKLYN',
#  u'workAreaFormatIndicatorIn': u'C',
#  u'xCoordinate': u'0998222',
#  u'xCoordinateHighAddressEnd': u'0998319',
#  u'xCoordinateLowAddressEnd': u'0998206',
#  u'xCoordinateOfCenterofCurvature': u'0000000',
#  u'yCoordinate': u'0154335',
#  u'yCoordinateHighAddressEnd': u'0153692',
#  u'yCoordinateLowAddressEnd': u'0154464',
#  u'yCoordinateOfCenterofCurvature': u'0000000',
#  u'zipCode': u'11235'}

# %%
geoclient.blockface('Ocean Avenue', 'Avenue Y', 'Avenue Z', 'Brooklyn')
# Out:
# {u'boroughCode1In': u'3',
#  u'coincidentSegmentCount': u'1',
#  u'crossStreetNamesFlagIn': u'E',
#  u'dcpPreferredLgcForStreet1': u'01',
#  u'dcpPreferredLgcForStreet2': u'01',
#  u'dcpPreferredLgcForStreet3': u'01',
#  u'dotStreetLightContractorArea': u'3',
#  u'firstBoroughName': u'BROOKLYN',
#  u'firstStreetCode': u'36753001010',
#  u'firstStreetNameNormalized': u'OCEAN AVENUE',
#  u'fromLgc1': u'01',
#  u'fromNode': u'0017059',
#  u'fromXCoordinate': u'0998206',
#  u'fromYCoordinate': u'0154464',
#  u'genericId': u'0033257',
#  u'geosupportFunctionCode': u'3',
#  u'geosupportReturnCode': u'00',
#  u'highCrossStreetB5SC1': u'314880',
#  u'leftSegment1990CensusTract': u' 59401',
#  u'leftSegment2000CensusBlock': u'5001',
#  u'leftSegment2000CensusTract': u' 59401',
#  u'leftSegment2010CensusBlock': u'5001',
#  u'leftSegment2010CensusTract': u' 59401',
#  u'leftSegmentAssemblyDistrict': u'41',
#  u'leftSegmentCommunityDistrict': u'315',
#  u'leftSegmentCommunityDistrictBoroughCode': u'3',
#  u'leftSegmentCommunityDistrictNumber': u'15',
#  u'leftSegmentCommunitySchoolDistrict': u'22',
#  u'leftSegmentDynamicBlock': u'501',
#  u'leftSegmentElectionDistrict': u'081',
#  u'leftSegmentFireBattalion': u'43',
#  u'leftSegmentFireCompanyNumber': u'246',
#  u'leftSegmentFireCompanyType': u'E',
#  u'leftSegmentFireDivision': u'08',
#  u'leftSegmentHealthArea': u'8722',
#  u'leftSegmentHealthCenterDistrict': u'37',
#  u'leftSegmentHighHouseNumber': u'0002979',
#  u'leftSegmentInterimAssistanceEligibilityIndicator': u'I',
#  u'leftSegmentLowHouseNumber': u'0002897',
#  u'leftSegmentNta': u'BK17',
#  u'leftSegmentNtaName': u'Sheepshead Bay-Gerritsen Beach-Manhattan Beach',
#  u'leftSegmentPolicePatrolBoroughCommand': u'4',
#  u'leftSegmentPolicePrecinct': u'061',
#  u'leftSegmentZipCode': u'11235',
#  u'legacyId': u'0026242',
#  u'lengthOfSegmentInFeet': u'00780',
#  u'lgc1': u'01',
#  u'lionBoroughCode': u'3',
#  u'lionFaceCode': u'5976',
#  u'lionKey': u'3597607080',
#  u'lionSequenceNumber': u'07080',
#  u'locationalStatusOfSegment': u'X',
#  u'lowCrossStreetB5SC1': u'314830',
#  u'lowCrossStreetB5SC2': u'340650',
#  u'modeSwitchIn': u'X',
#  u'numberOfCrossStreetB5SCsHighAddressEnd': u'1',
#  u'numberOfCrossStreetB5SCsLowAddressEnd': u'2',
#  u'numberOfStreetCodesAndNamesInList': u'03',
#  u'physicalId': u'0038421',
#  u'rightSegment1990CensusTract': u' 592  ',
#  u'rightSegment2000CensusBlock': u'3000',
#  u'rightSegment2000CensusTract': u' 592  ',
#  u'rightSegment2010CensusBlock': u'3000',
#  u'rightSegment2010CensusTract': u' 592  ',
#  u'rightSegmentAssemblyDistrict': u'41',
#  u'rightSegmentCommunityDistrict': u'315',
#  u'rightSegmentCommunityDistrictBoroughCode': u'3',
#  u'rightSegmentCommunityDistrictNumber': u'15',
#  u'rightSegmentCommunitySchoolDistrict': u'22',
#  u'rightSegmentDynamicBlock': u'303',
#  u'rightSegmentElectionDistrict': u'081',
#  u'rightSegmentFireBattalion': u'43',
#  u'rightSegmentFireCompanyNumber': u'246',
#  u'rightSegmentFireCompanyType': u'E',
#  u'rightSegmentFireDivision': u'08',
#  u'rightSegmentHealthArea': u'8721',
#  u'rightSegmentHealthCenterDistrict': u'37',
#  u'rightSegmentHighHouseNumber': u'0002980',
#  u'rightSegmentInterimAssistanceEligibilityIndicator': u'I',
#  u'rightSegmentLowHouseNumber': u'0002898',
#  u'rightSegmentNta': u'BK17',
#  u'rightSegmentNtaName': u'Sheepshead Bay-Gerritsen Beach-Manhattan Beach',
#  u'rightSegmentPolicePatrolBoroughCommand': u'4',
#  u'rightSegmentPolicePrecinct': u'061',
#  u'rightSegmentZipCode': u'11235',
#  u'roadwayType': u'1',
#  u'sanitationSnowPriorityCode': u'P',
#  u'secondStreetCode': u'31483001010',
#  u'secondStreetNameNormalized': u'AVENUE Y',
#  u'segmentAzimuth': u'278',
#  u'segmentIdentifier': u'0026242',
#  u'segmentOrientation': u'S',
#  u'segmentTypeCode': u'U',
#  u'streetCode1': u'31483001',
#  u'streetCode2': u'34065001',
#  u'streetCode6': u'31488001',
#  u'streetName1': u'AVENUE Y',
#  u'streetName1In': u'OCEAN AVENUE',
#  u'streetName2': u'FIREMANS CORNER SHEEPSHEAD BAY',
#  u'streetName2In': u'AVENUE Y',
#  u'streetName3In': u'AVENUE Z',
#  u'streetName6': u'AVENUE Z',
#  u'streetStatus': u'2',
#  u'streetWidth': u'70',
#  u'thirdStreetCode': u'31488001010',
#  u'thirdStreetNameNormalized': u'AVENUE Z',
#  u'toLgc1': u'01',
#  u'toNode': u'0017053',
#  u'toXCoordinate': u'0998319',
#  u'toYCoordinate': u'0153692',
#  u'trafficDirection': u'T',
#  u'workAreaFormatIndicatorIn': u'C'}

# %%
geoclient.intersection('Ocean Avenue', 'Avenue X', 'Brooklyn')
# Out:
# {u'assemblyDistrict': u'41',
#  u'boroughCode1In': u'3',
#  u'censusTract1990': u' 592  ',
#  u'censusTract2000': u' 592  ',
#  u'censusTract2010': u' 592  ',
#  u'cityCouncilDistrict': u'48',
#  u'civilCourtDistrict': u'08',
#  u'communityDistrict': u'315',
#  u'communityDistrictBoroughCode': u'3',
#  u'communityDistrictNumber': u'15',
#  u'communitySchoolDistrict': u'22',
#  u'congressionalDistrict': u'09',
#  u'crossStreetNamesFlagIn': u'E',
#  u'dcpPreferredLgcForStreet1': u'01',
#  u'dcpPreferredLgcForStreet2': u'01',
#  u'dotStreetLightContractorArea': u'3',
#  u'fireBattalion': u'43',
#  u'fireCompanyNumber': u'246',
#  u'fireCompanyType': u'E',
#  u'fireDivision': u'08',
#  u'firstBoroughName': u'BROOKLYN',
#  u'firstStreetCode': u'36753001010',
#  u'firstStreetNameNormalized': u'OCEAN AVENUE',
#  u'geosupportFunctionCode': u'2',
#  u'geosupportReturnCode': u'00',
#  u'healthArea': u'8721',
#  u'healthCenterDistrict': u'37',
#  u'instructionalRegion': u'BS',
#  u'interimAssistanceEligibilityIndicator': u'I',
#  u'intersectingStreet1': u'314780',
#  u'intersectingStreet2': u'367530',
#  u'latitude': 40.59275230613326,
#  u'lionNodeNumber': u'0017062',
#  u'listOfPairsOfLevelCodes': u'MMMM',
#  u'longitude': -73.95015246435702,
#  u'numberOfIntersectingStreets': u'2',
#  u'numberOfStreetCodesAndNamesInList': u'02',
#  u'policePatrolBoroughCommand': u'4',
#  u'policePrecinct': u'061',
#  u'sanbornBoroughCode1': u'3',
#  u'sanbornBoroughCode2': u'3',
#  u'sanbornPageNumber1': u'018',
#  u'sanbornPageNumber2': u'017',
#  u'sanbornVolumeNumber1': u'14',
#  u'sanbornVolumeNumber2': u'14',
#  u'sanitationCollectionSchedulingSectionAndSubsection': u'3E',
#  u'sanitationDistrict': u'315',
#  u'secondStreetCode': u'31478001010',
#  u'secondStreetNameNormalized': u'AVENUE X',
#  u'stateSenatorialDistrict': u'19',
#  u'streetCode1': u'31478001',
#  u'streetCode2': u'36753001',
#  u'streetName1': u'AVENUE X',
#  u'streetName1In': u'OCEAN AVENUE',
#  u'streetName2': u'OCEAN AVENUE',
#  u'streetName2In': u'AVENUE X',
#  u'workAreaFormatIndicatorIn': u'C',
#  u'xCoordinate': u'0998094',
#  u'yCoordinate': u'0155236',
#  u'zipCode': u'11235'}

# %%
geoclient.place('One World Trade Center', 'Manhattan')
# Out:
# {u'assemblyDistrict': u'65',
#  u'bbl': u'1000580001',
#  u'bblBoroughCode': u'1',
#  u'bblTaxBlock': u'00058',
#  u'bblTaxLot': u'0001',
#  u'boardOfElectionsPreferredLgc': u'1',
#  u'boePreferredStreetName': u'ONE WORLD TRADE CENTER',
#  u'boePreferredstreetCode': u'14560102',
#  u'boroughCode1In': u'1',
#  u'buildingIdentificationNumber': u'1088469',
#  u'censusBlock2000': u'4000',
#  u'censusBlock2010': u'1000',
#  u'censusTract1990': u'  13  ',
#  u'censusTract2000': u'  13  ',
#  u'censusTract2010': u'  13  ',
#  u'cityCouncilDistrict': u'01',
#  u'civilCourtDistrict': u'01',
#  u'coincidentSegmentCount': u'2',
#  u'communityDistrict': u'101',
#  u'communityDistrictBoroughCode': u'1',
#  u'communityDistrictNumber': u'01',
#  u'communitySchoolDistrict': u'02',
#  u'condominiumBillingBbl': u'0000000000',
#  u'congressionalDistrict': u'10',
#  u'cooperativeIdNumber': u'0000',
#  u'cornerCode': u'CR',
#  u'crossStreetNamesFlagIn': u'E',
#  u'dcpCommercialStudyArea': u'11003',
#  u'dcpPreferredLgc': u'02',
#  u'dotStreetLightContractorArea': u'1',
#  u'dynamicBlock': u'402',
#  u'electionDistrict': u'093',
#  u'featureTypeCode': u'W',
#  u'fireBattalion': u'01',
#  u'fireCompanyNumber': u'010',
#  u'fireCompanyType': u'E',
#  u'fireDivision': u'01',
#  u'firstBoroughName': u'MANHATTAN',
#  u'firstStreetCode': u'14560102030',
#  u'firstStreetNameNormalized': u'ONE WORLD TRADE CENTER',
#  u'fromLionNodeId': u'0015203',
#  u'fromPreferredLgcsFirstSetOf5': u'01',
#  u'genericId': u'0133255',
#  u'geosupportFunctionCode': u'1B',
#  u'geosupportReturnCode': u'01',
#  u'geosupportReturnCode2': u'01',
#  u'gi5DigitStreetCode1': u'45601',
#  u'gi5DigitStreetCode10': u'15350',
#  u'gi5DigitStreetCode11': u'45601',
#  u'gi5DigitStreetCode12': u'21790',
#  u'gi5DigitStreetCode13': u'13940',
#  u'gi5DigitStreetCode14': u'13940',
#  u'gi5DigitStreetCode15': u'13940',
#  u'gi5DigitStreetCode16': u'13940',
#  u'gi5DigitStreetCode17': u'13940',
#  u'gi5DigitStreetCode18': u'13940',
#  u'gi5DigitStreetCode19': u'45601',
#  u'gi5DigitStreetCode2': u'21230',
#  u'gi5DigitStreetCode20': u'45601',
#  u'gi5DigitStreetCode21': u'21790',
#  u'gi5DigitStreetCode3': u'45601',
#  u'gi5DigitStreetCode4': u'21790',
#  u'gi5DigitStreetCode5': u'45601',
#  u'gi5DigitStreetCode6': u'15350',
#  u'gi5DigitStreetCode7': u'45601',
#  u'gi5DigitStreetCode8': u'21790',
#  u'gi5DigitStreetCode9': u'45601',
#  u'giBoroughCode1': u'1',
#  u'giBoroughCode10': u'1',
#  u'giBoroughCode11': u'1',
#  u'giBoroughCode12': u'1',
#  u'giBoroughCode13': u'1',
#  u'giBoroughCode14': u'1',
#  u'giBoroughCode15': u'1',
#  u'giBoroughCode16': u'1',
#  u'giBoroughCode17': u'1',
#  u'giBoroughCode18': u'1',
#  u'giBoroughCode19': u'1',
#  u'giBoroughCode2': u'1',
#  u'giBoroughCode20': u'1',
#  u'giBoroughCode21': u'1',
#  u'giBoroughCode3': u'1',
#  u'giBoroughCode4': u'1',
#  u'giBoroughCode5': u'1',
#  u'giBoroughCode6': u'1',
#  u'giBoroughCode7': u'1',
#  u'giBoroughCode8': u'1',
#  u'giBoroughCode9': u'1',
#  u'giBuildingIdentificationNumber1': u'1088469',
#  u'giBuildingIdentificationNumber10': u'1088797',
#  u'giBuildingIdentificationNumber11': u'1088797',
#  u'giBuildingIdentificationNumber12': u'1088798',
#  u'giBuildingIdentificationNumber13': u'1088798',
#  u'giBuildingIdentificationNumber14': u'1088798',
#  u'giBuildingIdentificationNumber15': u'1088799',
#  u'giBuildingIdentificationNumber16': u'1088800',
#  u'giBuildingIdentificationNumber17': u'1088802',
#  u'giBuildingIdentificationNumber18': u'1088803',
#  u'giBuildingIdentificationNumber19': u'1089308',
#  u'giBuildingIdentificationNumber2': u'1088469',
#  u'giBuildingIdentificationNumber20': u'1089308',
#  u'giBuildingIdentificationNumber21': u'1089309',
#  u'giBuildingIdentificationNumber3': u'1088469',
#  u'giBuildingIdentificationNumber4': u'1088795',
#  u'giBuildingIdentificationNumber5': u'1088795',
#  u'giBuildingIdentificationNumber6': u'1088795',
#  u'giBuildingIdentificationNumber7': u'1088795',
#  u'giBuildingIdentificationNumber8': u'1088797',
#  u'giBuildingIdentificationNumber9': u'1088797',
#  u'giDcpPreferredLgc1': u'02',
#  u'giDcpPreferredLgc10': u'01',
#  u'giDcpPreferredLgc11': u'04',
#  u'giDcpPreferredLgc12': u'01',
#  u'giDcpPreferredLgc13': u'01',
#  u'giDcpPreferredLgc14': u'02',
#  u'giDcpPreferredLgc15': u'04',
#  u'giDcpPreferredLgc16': u'05',
#  u'giDcpPreferredLgc17': u'07',
#  u'giDcpPreferredLgc18': u'08',
#  u'giDcpPreferredLgc19': u'01',
#  u'giDcpPreferredLgc2': u'01',
#  u'giDcpPreferredLgc20': u'03',
#  u'giDcpPreferredLgc21': u'01',
#  u'giDcpPreferredLgc3': u'01',
#  u'giDcpPreferredLgc4': u'01',
#  u'giDcpPreferredLgc5': u'01',
#  u'giDcpPreferredLgc6': u'01',
#  u'giDcpPreferredLgc7': u'05',
#  u'giDcpPreferredLgc8': u'01',
#  u'giDcpPreferredLgc9': u'01',
#  u'giGeographicIdentifier1': u'X',
#  u'giGeographicIdentifier10': u'W',
#  u'giGeographicIdentifier11': u'X',
#  u'giGeographicIdentifier13': u'G',
#  u'giGeographicIdentifier14': u'X',
#  u'giGeographicIdentifier15': u'X',
#  u'giGeographicIdentifier16': u'X',
#  u'giGeographicIdentifier17': u'X',
#  u'giGeographicIdentifier18': u'X',
#  u'giGeographicIdentifier20': u'X',
#  u'giGeographicIdentifier6': u'W',
#  u'giGeographicIdentifier7': u'X',
#  u'giHighHouseNumber12': u'180',
#  u'giHighHouseNumber19': u'2',
#  u'giHighHouseNumber2': u'285',
#  u'giHighHouseNumber21': u'185',
#  u'giHighHouseNumber3': u'1',
#  u'giHighHouseNumber4': u'150',
#  u'giHighHouseNumber5': u'4',
#  u'giHighHouseNumber8': u'175',
#  u'giHighHouseNumber9': u'3',
#  u'giLowHouseNumber12': u'180',
#  u'giLowHouseNumber19': u'2',
#  u'giLowHouseNumber2': u'285',
#  u'giLowHouseNumber21': u'185',
#  u'giLowHouseNumber3': u'1',
#  u'giLowHouseNumber4': u'150',
#  u'giLowHouseNumber5': u'4',
#  u'giLowHouseNumber8': u'175',
#  u'giLowHouseNumber9': u'3',
#  u'giSideOfStreetIndicator1': u'L',
#  u'giSideOfStreetIndicator11': u'L',
#  u'giSideOfStreetIndicator12': u'L',
#  u'giSideOfStreetIndicator13': u'R',
#  u'giSideOfStreetIndicator14': u'R',
#  u'giSideOfStreetIndicator15': u'R',
#  u'giSideOfStreetIndicator16': u'R',
#  u'giSideOfStreetIndicator17': u'R',
#  u'giSideOfStreetIndicator18': u'R',
#  u'giSideOfStreetIndicator19': u'L',
#  u'giSideOfStreetIndicator2': u'L',
#  u'giSideOfStreetIndicator20': u'L',
#  u'giSideOfStreetIndicator21': u'R',
#  u'giSideOfStreetIndicator3': u'L',
#  u'giSideOfStreetIndicator4': u'L',
#  u'giSideOfStreetIndicator5': u'L',
#  u'giSideOfStreetIndicator7': u'L',
#  u'giSideOfStreetIndicator8': u'R',
#  u'giSideOfStreetIndicator9': u'L',
#  u'giStreetCode1': u'14560102',
#  u'giStreetCode10': u'11535001',
#  u'giStreetCode11': u'14560104',
#  u'giStreetCode12': u'12179001',
#  u'giStreetCode13': u'11394001',
#  u'giStreetCode14': u'11394002',
#  u'giStreetCode15': u'11394004',
#  u'giStreetCode16': u'11394005',
#  u'giStreetCode17': u'11394007',
#  u'giStreetCode18': u'11394008',
#  u'giStreetCode19': u'14560101',
#  u'giStreetCode2': u'12123001',
#  u'giStreetCode20': u'14560103',
#  u'giStreetCode21': u'12179001',
#  u'giStreetCode3': u'14560101',
#  u'giStreetCode4': u'12179001',
#  u'giStreetCode5': u'14560101',
#  u'giStreetCode6': u'11535001',
#  u'giStreetCode7': u'14560105',
#  u'giStreetCode8': u'12179001',
#  u'giStreetCode9': u'14560101',
#  u'giStreetName1': u'ONE WORLD TRADE CENTER',
#  u'giStreetName10': u'CHURCH STREET',
#  u'giStreetName11': u'THREE WORLD TRADE CENTER',
#  u'giStreetName12': u'GREENWICH STREET',
#  u'giStreetName13': u'NATIONAL 9/11 MEMORIAL',
#  u'giStreetName14': u'NATIONAL 9/11 MUSEUM',
#  u'giStreetName15': u'SOUTH MEMORIAL REFLECTING POOL',
#  u'giStreetName16': u'NORTH MEMORIAL REFLECTING POOL',
#  u'giStreetName17': u'9/11 MEMORIAL WEST VENT NORTH',
#  u'giStreetName18': u'9/11 MEMORIAL WEST VENT SOUTH',
#  u'giStreetName19': u'WORLD TRADE CENTER',
#  u'giStreetName2': u'FULTON STREET',
#  u'giStreetName20': u'TWO WORLD TRADE CENTER',
#  u'giStreetName21': u'GREENWICH STREET',
#  u'giStreetName3': u'WORLD TRADE CENTER',
#  u'giStreetName4': u'GREENWICH STREET',
#  u'giStreetName5': u'WORLD TRADE CENTER',
#  u'giStreetName6': u'CHURCH STREET',
#  u'giStreetName7': u'FOUR WORLD TRADE CENTER',
#  u'giStreetName8': u'GREENWICH STREET',
#  u'giStreetName9': u'WORLD TRADE CENTER',
#  u'healthArea': u'7700',
#  u'healthCenterDistrict': u'15',
#  u'highBblOfThisBuildingsCondominiumUnits': u'1000580001',
#  u'highCrossStreetB5SC1': u'111115',
#  u'highCrossStreetCode1': u'11111504',
#  u'highCrossStreetName1': u'WEST STREET',
#  u'highHouseNumberOfBlockfaceSortFormat': u'000000000AA',
#  u'hurricaneEvacuationZone': u'1',
#  u'individualSegmentLength': u'00173',
#  u'instructionalRegion': u'MS',
#  u'interimAssistanceEligibilityIndicator': u'I',
#  u'internalLabelXCoordinate': u'0980828',
#  u'internalLabelYCoordinate': u'0198546',
#  u'irregularlyShapedLotFlag': u'I',
#  u'latitude': 40.713099086327894,
#  u'latitudeInternalLabel': 40.71163895221414,
#  u'legacySegmentId': u'0162334',
#  u'lionBoroughCode': u'1',
#  u'lionBoroughCodeForVanityAddress': u'1',
#  u'lionFaceCode': u'4550',
#  u'lionFaceCodeForVanityAddress': u'4550',
#  u'lionKey': u'1455000040',
#  u'lionKeyForVanityAddress': u'1455000040',
#  u'lionSequenceNumber': u'00040',
#  u'lionSequenceNumberForVanityAddress': u'00040',
#  u'listOf4Lgcs': u'02',
#  u'listOfGeographicIdentifiersOverflowFlag': u'E',
#  u'longitude': -74.01306152916293,
#  u'longitudeInternalLabel': -74.01234343376866,
#  u'lowBblOfThisBuildingsCondominiumUnits': u'1000580001',
#  u'lowCrossStreetB5SC1': u'133390',
#  u'lowCrossStreetCode1': u'13339001',
#  u'lowCrossStreetName1': u'WASHINGTON STREET',
#  u'lowHouseNumberOfBlockfaceSortFormat': u'000000000AA',
#  u'lowHouseNumberOfDefiningAddressRange': u'000002000AA',
#  u'message': u'1 VESEY STREET IS THE UNDERLYING ADDRESS OF ONE WORLD TRADE CENTER',
#  u'message2': u'LOT HAS MORE ITEMS THAN LISTED',
#  u'noCrossStreetCalculationFlag': u'Y',
#  u'nta': u'MN25',
#  u'ntaName': u'Battery Park City-Lower Manhattan',
#  u'numberOfCrossStreetB5SCsHighAddressEnd': u'1',
#  u'numberOfCrossStreetB5SCsLowAddressEnd': u'1',
#  u'numberOfCrossStreetsHighAddressEnd': u'1',
#  u'numberOfCrossStreetsLowAddressEnd': u'1',
#  u'numberOfEntriesInListOfGeographicIdentifiers': u'0021',
#  u'numberOfExistingStructuresOnLot': u'0011',
#  u'numberOfStreetFrontagesOfLot': u'08',
#  u'physicalId': u'0146687',
#  u'policePatrolBoroughCommand': u'1',
#  u'policePrecinct': u'001',
#  u'reasonCode': u'V',
#  u'reasonCode1a': u'A',
#  u'reasonCode1e': u'V',
#  u'reasonCode2': u'A',
#  u'returnCode1a': u'01',
#  u'returnCode1e': u'01',
#  u'roadwayType': u'1',
#  u'rpadBuildingClassificationCode': u'O4',
#  u'rpadSelfCheckCodeForBbl': u'6',
#  u'sanbornBoroughCode': u'1',
#  u'sanbornPageNumber': u'038',
#  u'sanbornVolumeNumber': u'01',
#  u'sanbornVolumeNumberSuffix': u'S',
#  u'sanitationCollectionSchedulingSectionAndSubsection': u'1A',
#  u'sanitationDistrict': u'101',
#  u'sanitationRecyclingCollectionSchedule': u'EF',
#  u'sanitationRegularCollectionSchedule': u'MWF',
#  u'sanitationSnowPriorityCode': u'P',
#  u'segmentAzimuth': u'149',
#  u'segmentIdentifier': u'0259549',
#  u'segmentLengthInFeet': u'00173',
#  u'segmentOrientation': u'W',
#  u'segmentTypeCode': u'U',
#  u'sideOfStreetIndicator': u'L',
#  u'sideOfStreetOfVanityAddress': u'L',
#  u'specialAddressGeneratedRecordFlag': u'X',
#  u'splitLowHouseNumber': u'000002000AA',
#  u'stateSenatorialDistrict': u'26',
#  u'streetName1In': u'ONE WORLD TRADE CENTER',
#  u'streetStatus': u'2',
#  u'taxMapNumberSectionAndVolume': u'10102',
#  u'toLionNodeId': u'0015199',
#  u'toPreferredLgcsFirstSetOf5': u'04',
#  u'trafficDirection': u'P',
#  u'underlyingHnsOnTrueStreet': u'000001000AA',
#  u'underlyingStreetCode': u'13270001',
#  u'uspsPreferredCityName': u'NEW YORK',
#  u'workAreaFormatIndicatorIn': u'C',
#  u'xCoordinate': u'0980629',
#  u'xCoordinateHighAddressEnd': u'0980437',
#  u'xCoordinateLowAddressEnd': u'0980772',
#  u'xCoordinateOfCenterofCurvature': u'0000000',
#  u'yCoordinate': u'0199078',
#  u'yCoordinateHighAddressEnd': u'0199294',
#  u'yCoordinateLowAddressEnd': u'0199103',
#  u'yCoordinateOfCenterofCurvature': u'0000000',
#  u'zipCode': u'10007'}
