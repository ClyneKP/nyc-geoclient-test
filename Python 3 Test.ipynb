# %% [markdown]
# # NYC Geoclient Tool
#
# This notebook contains some live results from running New York City's [Geoclient API](http://developer.cityofnewyork.us/api/geoclient-api).
#
# The NYC Geoclient is a comprehensive REST API endpoint which returns all geographical data about an address, a bin, a borough-block-lot, a street intersection, a blockface, or a known place. It attempts to be comprehensive, pooling together GIS resources from dozens of disparate databases in attempting to return its answer. As a result it returns extremely verbose answers; you can understand the finer points of each of the returned parameters by reading the API's [extensive documentation](https://api.cityofnewyork.us/geoclient/v1/doc).
#
# This notebook is intended to confirm the cross-version compatibility of [my pull request to the Geoclient codebase](https://github.com/talos/nyc-geoclient/pull/3). Run this note in Python 3 and then in Python 2 to confirm cross-version compatibility.

# %%
from api import Geoclient

# %%
help(Geoclient)
# Out:
# Help on class Geoclient in module api:
#
# class Geoclient(builtins.object)
#  |  This object's methods provide access to the NYC Geoclient REST API.
#  |  You must have registered an app with the NYC Developer Portal
#  |  (http://developer.cityofnewyork.us/api/geoclient-api-beta), and make sure
#  |  that you check off access to the Geoclient API for the application.  Take
#  |  note of the Application's ID and key.  You will not be able to use the ID
#  |  and key until DoITT approves you -- this could take several days, and you
#  |  will receive an email when this happens.  There isn't any indication of
#  |  your status on the dashboard, but all requests will return a 403 until you
#  |  are approved.
#  |  All methods return a dict, whether or not the geocoding succeeded.  If it
#  |  failed, the dict will have a `message` key with information on why it
#  |  failed.
#  |  :param app_id:
#  |      Your NYC Geoclient application ID.
#  |  :param app_key:
#  |      Your NYC Geoclient application key.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, app_id, app_key)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  address(self, houseNumber, street, borough)
#  |      Given a valid address, provides blockface-level, property-level, and
#  |      political information.
#  |      :param houseNumber:
#  |          The house number to look up.
#  |      :param street:
#  |          The name of the street to look up.
#  |      :param borough:
#  |          The borough to look within.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :returns: A dict with blockface-level, property-level, and political
#  |          information.
#  |
#  |  address_zip(self, houseNumber, street, zip)
#  |      Like the above address function, except it uses "zip code" instead of borough
#  |      :param houseNumber:
#  |          The house number to look up.
#  |      :param street:
#  |          The name of the street to look up
#  |      :param zip:
#  |          The zip code of the address to look up.
#  |      :returns: A dict with blockface-level, property-level, and political
#  |          information.
#  |
#  |  bbl(self, borough, block, lot)
#  |      Given a valid borough, block, and lot provides property-level
#  |      information.
#  |      :param borough:
#  |          The borough to look within.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :param block:
#  |          The tax block to look up.
#  |      :param lot:
#  |          The tax lot to look up.
#  |      :returns: A dict with property-level information.
#  |
#  |  bin(self, bin)
#  |      Given a valid building identification number (BIN) provides
#  |      property-level information.
#  |      :param bin:
#  |          The BIN to look up.
#  |      :returns: A dict with property-level information.
#  |
#  |  blockface(self, onStreet, crossStreetOne, crossStreetTwo, borough, boroughCrossStreetOne=None, boroughCrossStreetTwo=None, compassDirection=None)
#  |      Given a valid borough, "on street" and cross streets provides
#  |      blockface-level information.
#  |      :param onStreet:
#  |          "On street" (street name of target blockface).
#  |      :param crossStreetOne:
#  |          First cross street of blockface.
#  |      :param crossStreetTwo:
#  |          Second cross street of blockface.
#  |      :param borough:
#  |          The borough to look within.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :param boroughCrossStreetOne:
#  |          (optional) Borough of first cross street. Defaults to value of
#  |          borough parameter if not supplied.
#  |      :param boroughCrossStreetTwo:
#  |          (optional) Borough of second cross street. Defaults to value of
#  |          borough parameter if not supplied.
#  |      :param compassDirection:
#  |          (optional) Used to request information about only one side of the
#  |          street. Valid values are: N, S, E or W.
#  |      :returns: A dict with blockface-level information.
#  |
#  |  intersection(self, crossStreetOne, crossStreetTwo, borough, boroughCrossStreetTwo=None, compassDirection=None)
#  |      Given a valid borough and cross streets returns information for the
#  |      point defined by the two streets.
#  |      :param crossStreetOne:
#  |          First cross street
#  |      :param crossStreetTwo:
#  |          Second cross street
#  |      :param borough:
#  |          Borough of first cross street or of all cross streets if no other
#  |          borough parameter is supplied.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :param boroughCrossStreetTwo:
#  |          (optional) Borough of second cross street. If not supplied, assumed
#  |          to be same as borough parameter.  Must be 'Bronx', 'Brooklyn',
#  |          'Manhattan', 'Queens', or 'Staten Island' (case-insensitive).
#  |      :param compassDirection:
#  |          (optional) Optional. for most requests. Required for streets that
#  |          intersect more than once. Valid values are: N, S, E or W.
#  |      :returns: A dict with intersection-level information.
#  |
#  |  place(self, name, borough)
#  |      Same as 'Address' above using well-known NYC place name for input.
#  |      :param name:
#  |          Place name of well-known NYC location.
#  |      :param borough:
#  |          Must be 'Bronx', 'Brooklyn', 'Manhattan', 'Queens', or 'Staten
#  |          Island' (case-insensitive).
#  |      :returns: A dict with place-level information.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  BASE_URL = 'https://api.cityofnewyork.us/geoclient/v1/'

# %%
geoclient = Geoclient(app_id='e8641bad', app_key='22c53431c17717ffa7620fa546dd1272')

# %% [markdown]
# `address`, `addresszip`, `bin`, `bbl` all return the same output, just with different input.

# %%
geoclient.address('2900', 'Ocean Avenue', 'Brooklyn')
# Out:
# {'assemblyDistrict': '41',
#  'bbl': '3074407501',
#  'bblBoroughCode': '3',
#  'bblTaxBlock': '07440',
#  'bblTaxLot': '7501',
#  'boardOfElectionsPreferredLgc': '1',
#  'boePreferredStreetName': 'OCEAN AVENUE',
#  'boePreferredstreetCode': '36753001',
#  'boroughCode1In': '3',
#  'buildingIdentificationNumber': '3204172',
#  'censusBlock2000': '3000',
#  'censusBlock2010': '3000',
#  'censusTract1990': ' 592  ',
#  'censusTract2000': ' 592  ',
#  'censusTract2010': ' 592  ',
#  'cityCouncilDistrict': '48',
#  'civilCourtDistrict': '08',
#  'coincidentSegmentCount': '1',
#  'communityDistrict': '315',
#  'communityDistrictBoroughCode': '3',
#  'communityDistrictNumber': '15',
#  'communitySchoolDistrict': '22',
#  'condominiumBillingBbl': '3074407501',
#  'condominiumFlag': 'C',
#  'congressionalDistrict': '09',
#  'cooperativeIdNumber': '0000',
#  'cornerCode': 'SW',
#  'crossStreetNamesFlagIn': 'E',
#  'dcpPreferredLgc': '01',
#  'dofCondominiumIdentificationNumber': '0014',
#  'dotStreetLightContractorArea': '3',
#  'dynamicBlock': '303',
#  'electionDistrict': '081',
#  'fireBattalion': '43',
#  'fireCompanyNumber': '246',
#  'fireCompanyType': 'E',
#  'fireDivision': '08',
#  'firstBoroughName': 'BROOKLYN',
#  'firstStreetCode': '36753001010',
#  'firstStreetNameNormalized': 'OCEAN AVENUE',
#  'fromLionNodeId': '0017059',
#  'fromPreferredLgcsFirstSetOf5': '0101',
#  'genericId': '0033257',
#  'geosupportFunctionCode': '1B',
#  'geosupportReturnCode': '00',
#  'geosupportReturnCode2': '00',
#  'gi5DigitStreetCode1': '67530',
#  'gi5DigitStreetCode2': '14830',
#  'giBoroughCode1': '3',
#  'giBoroughCode2': '3',
#  'giBuildingIdentificationNumber1': '3204172',
#  'giBuildingIdentificationNumber2': '3204172',
#  'giDcpPreferredLgc1': '01',
#  'giDcpPreferredLgc2': '01',
#  'giHighHouseNumber1': '2900',
#  'giHighHouseNumber2': '1930',
#  'giLowHouseNumber1': '2900',
#  'giLowHouseNumber2': '1930',
#  'giSideOfStreetIndicator1': 'R',
#  'giSideOfStreetIndicator2': 'R',
#  'giStreetCode1': '36753001',
#  'giStreetCode2': '31483001',
#  'giStreetName1': 'OCEAN AVENUE',
#  'giStreetName2': 'AVENUE Y',
#  'healthArea': '8721',
#  'healthCenterDistrict': '37',
#  'highBblOfThisBuildingsCondominiumUnits': '3074401088',
#  'highCrossStreetB5SC1': '314880',
#  'highCrossStreetCode1': '31488001',
#  'highCrossStreetName1': 'AVENUE Z',
#  'highHouseNumberOfBlockfaceSortFormat': '002980000AA',
#  'houseNumber': '2900',
#  'houseNumberIn': '2900',
#  'houseNumberSortFormat': '002900000AA',
#  'hurricaneEvacuationZone': '1',
#  'instructionalRegion': 'BS',
#  'interimAssistanceEligibilityIndicator': 'I',
#  'internalLabelXCoordinate': '0998121',
#  'internalLabelYCoordinate': '0154305',
#  'latitude': 40.59027904122673,
#  'latitudeInternalLabel': 40.59019685587441,
#  'legacySegmentId': '0026242',
#  'lionBoroughCode': '3',
#  'lionBoroughCodeForVanityAddress': '3',
#  'lionFaceCode': '5976',
#  'lionFaceCodeForVanityAddress': '5976',
#  'lionKey': '3597607080',
#  'lionKeyForVanityAddress': '3597607080',
#  'lionSequenceNumber': '07080',
#  'lionSequenceNumberForVanityAddress': '07080',
#  'listOf4Lgcs': '01',
#  'longitude': -73.94969344311185,
#  'longitudeInternalLabel': -73.95005715779811,
#  'lowBblOfThisBuildingsCondominiumUnits': '3074401001',
#  'lowCrossStreetB5SC1': '314830',
#  'lowCrossStreetB5SC2': '340650',
#  'lowCrossStreetCode1': '31483001',
#  'lowCrossStreetCode2': '34065001',
#  'lowCrossStreetName1': 'AVENUE Y',
#  'lowCrossStreetName2': 'FIREMANS CORNER SHEEPSHEAD BAY',
#  'lowHouseNumberOfBlockfaceSortFormat': '002898000AA',
#  'lowHouseNumberOfDefiningAddressRange': '002900000AA',
#  'nta': 'BK17',
#  'ntaName': 'Sheepshead Bay-Gerritsen Beach-Manhattan Beach',
#  'numberOfCrossStreetB5SCsHighAddressEnd': '1',
#  'numberOfCrossStreetB5SCsLowAddressEnd': '2',
#  'numberOfCrossStreetsHighAddressEnd': '1',
#  'numberOfCrossStreetsLowAddressEnd': '2',
#  'numberOfEntriesInListOfGeographicIdentifiers': '0002',
#  'numberOfExistingStructuresOnLot': '0001',
#  'numberOfStreetFrontagesOfLot': '02',
#  'physicalId': '0038421',
#  'policePatrolBoroughCommand': '4',
#  'policePrecinct': '061',
#  'returnCode1a': '00',
#  'returnCode1e': '00',
#  'roadwayType': '1',
#  'rpadBuildingClassificationCode': 'R4',
#  'rpadSelfCheckCodeForBbl': '1',
#  'sanbornBoroughCode': '3',
#  'sanbornPageNumber': '005',
#  'sanbornVolumeNumber': '18',
#  'sanitationCollectionSchedulingSectionAndSubsection': '3D',
#  'sanitationDistrict': '315',
#  'sanitationRecyclingCollectionSchedule': 'ET',
#  'sanitationRegularCollectionSchedule': 'TF',
#  'sanitationSnowPriorityCode': 'P',
#  'segmentAzimuth': '278',
#  'segmentIdentifier': '0026242',
#  'segmentLengthInFeet': '00780',
#  'segmentOrientation': 'S',
#  'segmentTypeCode': 'U',
#  'selfCheckCodeOfBillingBbl': '1',
#  'sideOfStreetIndicator': 'R',
#  'sideOfStreetOfVanityAddress': 'R',
#  'splitLowHouseNumber': '002898000AA',
#  'stateSenatorialDistrict': '22',
#  'streetName1In': 'OCEAN AVENUE',
#  'streetStatus': '2',
#  'streetWidth': '70',
#  'taxMapNumberSectionAndVolume': '32205',
#  'toLionNodeId': '0017053',
#  'toPreferredLgcsFirstSetOf5': '01',
#  'trafficDirection': 'T',
#  'underlyingStreetCode': '36753001',
#  'uspsPreferredCityName': 'BROOKLYN',
#  'workAreaFormatIndicatorIn': 'C',
#  'xCoordinate': '0998222',
#  'xCoordinateHighAddressEnd': '0998319',
#  'xCoordinateLowAddressEnd': '0998206',
#  'xCoordinateOfCenterofCurvature': '0000000',
#  'yCoordinate': '0154335',
#  'yCoordinateHighAddressEnd': '0153692',
#  'yCoordinateLowAddressEnd': '0154464',
#  'yCoordinateOfCenterofCurvature': '0000000',
#  'zipCode': '11235'}

# %%
geoclient.blockface('Ocean Avenue', 'Avenue Y', 'Avenue Z', 'Brooklyn')
# Out:
# {'boroughCode1In': '3',
#  'coincidentSegmentCount': '1',
#  'crossStreetNamesFlagIn': 'E',
#  'dcpPreferredLgcForStreet1': '01',
#  'dcpPreferredLgcForStreet2': '01',
#  'dcpPreferredLgcForStreet3': '01',
#  'dotStreetLightContractorArea': '3',
#  'firstBoroughName': 'BROOKLYN',
#  'firstStreetCode': '36753001010',
#  'firstStreetNameNormalized': 'OCEAN AVENUE',
#  'fromLgc1': '01',
#  'fromNode': '0017059',
#  'fromXCoordinate': '0998206',
#  'fromYCoordinate': '0154464',
#  'genericId': '0033257',
#  'geosupportFunctionCode': '3',
#  'geosupportReturnCode': '00',
#  'highCrossStreetB5SC1': '314880',
#  'leftSegment1990CensusTract': ' 59401',
#  'leftSegment2000CensusBlock': '5001',
#  'leftSegment2000CensusTract': ' 59401',
#  'leftSegment2010CensusBlock': '5001',
#  'leftSegment2010CensusTract': ' 59401',
#  'leftSegmentAssemblyDistrict': '41',
#  'leftSegmentCommunityDistrict': '315',
#  'leftSegmentCommunityDistrictBoroughCode': '3',
#  'leftSegmentCommunityDistrictNumber': '15',
#  'leftSegmentCommunitySchoolDistrict': '22',
#  'leftSegmentDynamicBlock': '501',
#  'leftSegmentElectionDistrict': '081',
#  'leftSegmentFireBattalion': '43',
#  'leftSegmentFireCompanyNumber': '246',
#  'leftSegmentFireCompanyType': 'E',
#  'leftSegmentFireDivision': '08',
#  'leftSegmentHealthArea': '8722',
#  'leftSegmentHealthCenterDistrict': '37',
#  'leftSegmentHighHouseNumber': '0002979',
#  'leftSegmentInterimAssistanceEligibilityIndicator': 'I',
#  'leftSegmentLowHouseNumber': '0002897',
#  'leftSegmentNta': 'BK17',
#  'leftSegmentNtaName': 'Sheepshead Bay-Gerritsen Beach-Manhattan Beach',
#  'leftSegmentPolicePatrolBoroughCommand': '4',
#  'leftSegmentPolicePrecinct': '061',
#  'leftSegmentZipCode': '11235',
#  'legacyId': '0026242',
#  'lengthOfSegmentInFeet': '00780',
#  'lgc1': '01',
#  'lionBoroughCode': '3',
#  'lionFaceCode': '5976',
#  'lionKey': '3597607080',
#  'lionSequenceNumber': '07080',
#  'locationalStatusOfSegment': 'X',
#  'lowCrossStreetB5SC1': '314830',
#  'lowCrossStreetB5SC2': '340650',
#  'modeSwitchIn': 'X',
#  'numberOfCrossStreetB5SCsHighAddressEnd': '1',
#  'numberOfCrossStreetB5SCsLowAddressEnd': '2',
#  'numberOfStreetCodesAndNamesInList': '03',
#  'physicalId': '0038421',
#  'rightSegment1990CensusTract': ' 592  ',
#  'rightSegment2000CensusBlock': '3000',
#  'rightSegment2000CensusTract': ' 592  ',
#  'rightSegment2010CensusBlock': '3000',
#  'rightSegment2010CensusTract': ' 592  ',
#  'rightSegmentAssemblyDistrict': '41',
#  'rightSegmentCommunityDistrict': '315',
#  'rightSegmentCommunityDistrictBoroughCode': '3',
#  'rightSegmentCommunityDistrictNumber': '15',
#  'rightSegmentCommunitySchoolDistrict': '22',
#  'rightSegmentDynamicBlock': '303',
#  'rightSegmentElectionDistrict': '081',
#  'rightSegmentFireBattalion': '43',
#  'rightSegmentFireCompanyNumber': '246',
#  'rightSegmentFireCompanyType': 'E',
#  'rightSegmentFireDivision': '08',
#  'rightSegmentHealthArea': '8721',
#  'rightSegmentHealthCenterDistrict': '37',
#  'rightSegmentHighHouseNumber': '0002980',
#  'rightSegmentInterimAssistanceEligibilityIndicator': 'I',
#  'rightSegmentLowHouseNumber': '0002898',
#  'rightSegmentNta': 'BK17',
#  'rightSegmentNtaName': 'Sheepshead Bay-Gerritsen Beach-Manhattan Beach',
#  'rightSegmentPolicePatrolBoroughCommand': '4',
#  'rightSegmentPolicePrecinct': '061',
#  'rightSegmentZipCode': '11235',
#  'roadwayType': '1',
#  'sanitationSnowPriorityCode': 'P',
#  'secondStreetCode': '31483001010',
#  'secondStreetNameNormalized': 'AVENUE Y',
#  'segmentAzimuth': '278',
#  'segmentIdentifier': '0026242',
#  'segmentOrientation': 'S',
#  'segmentTypeCode': 'U',
#  'streetCode1': '31483001',
#  'streetCode2': '34065001',
#  'streetCode6': '31488001',
#  'streetName1': 'AVENUE Y',
#  'streetName1In': 'OCEAN AVENUE',
#  'streetName2': 'FIREMANS CORNER SHEEPSHEAD BAY',
#  'streetName2In': 'AVENUE Y',
#  'streetName3In': 'AVENUE Z',
#  'streetName6': 'AVENUE Z',
#  'streetStatus': '2',
#  'streetWidth': '70',
#  'thirdStreetCode': '31488001010',
#  'thirdStreetNameNormalized': 'AVENUE Z',
#  'toLgc1': '01',
#  'toNode': '0017053',
#  'toXCoordinate': '0998319',
#  'toYCoordinate': '0153692',
#  'trafficDirection': 'T',
#  'workAreaFormatIndicatorIn': 'C'}

# %%
geoclient.intersection('Ocean Avenue', 'Avenue X', 'Brooklyn')
# Out:
# {'assemblyDistrict': '41',
#  'boroughCode1In': '3',
#  'censusTract1990': ' 592  ',
#  'censusTract2000': ' 592  ',
#  'censusTract2010': ' 592  ',
#  'cityCouncilDistrict': '48',
#  'civilCourtDistrict': '08',
#  'communityDistrict': '315',
#  'communityDistrictBoroughCode': '3',
#  'communityDistrictNumber': '15',
#  'communitySchoolDistrict': '22',
#  'congressionalDistrict': '09',
#  'crossStreetNamesFlagIn': 'E',
#  'dcpPreferredLgcForStreet1': '01',
#  'dcpPreferredLgcForStreet2': '01',
#  'dotStreetLightContractorArea': '3',
#  'fireBattalion': '43',
#  'fireCompanyNumber': '246',
#  'fireCompanyType': 'E',
#  'fireDivision': '08',
#  'firstBoroughName': 'BROOKLYN',
#  'firstStreetCode': '36753001010',
#  'firstStreetNameNormalized': 'OCEAN AVENUE',
#  'geosupportFunctionCode': '2',
#  'geosupportReturnCode': '00',
#  'healthArea': '8721',
#  'healthCenterDistrict': '37',
#  'instructionalRegion': 'BS',
#  'interimAssistanceEligibilityIndicator': 'I',
#  'intersectingStreet1': '314780',
#  'intersectingStreet2': '367530',
#  'latitude': 40.59275230613326,
#  'lionNodeNumber': '0017062',
#  'listOfPairsOfLevelCodes': 'MMMM',
#  'longitude': -73.95015246435702,
#  'numberOfIntersectingStreets': '2',
#  'numberOfStreetCodesAndNamesInList': '02',
#  'policePatrolBoroughCommand': '4',
#  'policePrecinct': '061',
#  'sanbornBoroughCode1': '3',
#  'sanbornBoroughCode2': '3',
#  'sanbornPageNumber1': '018',
#  'sanbornPageNumber2': '017',
#  'sanbornVolumeNumber1': '14',
#  'sanbornVolumeNumber2': '14',
#  'sanitationCollectionSchedulingSectionAndSubsection': '3E',
#  'sanitationDistrict': '315',
#  'secondStreetCode': '31478001010',
#  'secondStreetNameNormalized': 'AVENUE X',
#  'stateSenatorialDistrict': '19',
#  'streetCode1': '31478001',
#  'streetCode2': '36753001',
#  'streetName1': 'AVENUE X',
#  'streetName1In': 'OCEAN AVENUE',
#  'streetName2': 'OCEAN AVENUE',
#  'streetName2In': 'AVENUE X',
#  'workAreaFormatIndicatorIn': 'C',
#  'xCoordinate': '0998094',
#  'yCoordinate': '0155236',
#  'zipCode': '11235'}

# %%
geoclient.place('One World Trade Center', 'Manhattan')
# Out:
# {'assemblyDistrict': '65',
#  'bbl': '1000580001',
#  'bblBoroughCode': '1',
#  'bblTaxBlock': '00058',
#  'bblTaxLot': '0001',
#  'boardOfElectionsPreferredLgc': '1',
#  'boePreferredStreetName': 'ONE WORLD TRADE CENTER',
#  'boePreferredstreetCode': '14560102',
#  'boroughCode1In': '1',
#  'buildingIdentificationNumber': '1088469',
#  'censusBlock2000': '4000',
#  'censusBlock2010': '1000',
#  'censusTract1990': '  13  ',
#  'censusTract2000': '  13  ',
#  'censusTract2010': '  13  ',
#  'cityCouncilDistrict': '01',
#  'civilCourtDistrict': '01',
#  'coincidentSegmentCount': '2',
#  'communityDistrict': '101',
#  'communityDistrictBoroughCode': '1',
#  'communityDistrictNumber': '01',
#  'communitySchoolDistrict': '02',
#  'condominiumBillingBbl': '0000000000',
#  'congressionalDistrict': '10',
#  'cooperativeIdNumber': '0000',
#  'cornerCode': 'CR',
#  'crossStreetNamesFlagIn': 'E',
#  'dcpCommercialStudyArea': '11003',
#  'dcpPreferredLgc': '02',
#  'dotStreetLightContractorArea': '1',
#  'dynamicBlock': '402',
#  'electionDistrict': '093',
#  'featureTypeCode': 'W',
#  'fireBattalion': '01',
#  'fireCompanyNumber': '010',
#  'fireCompanyType': 'E',
#  'fireDivision': '01',
#  'firstBoroughName': 'MANHATTAN',
#  'firstStreetCode': '14560102030',
#  'firstStreetNameNormalized': 'ONE WORLD TRADE CENTER',
#  'fromLionNodeId': '0015203',
#  'fromPreferredLgcsFirstSetOf5': '01',
#  'genericId': '0133255',
#  'geosupportFunctionCode': '1B',
#  'geosupportReturnCode': '01',
#  'geosupportReturnCode2': '01',
#  'gi5DigitStreetCode1': '45601',
#  'gi5DigitStreetCode10': '15350',
#  'gi5DigitStreetCode11': '45601',
#  'gi5DigitStreetCode12': '21790',
#  'gi5DigitStreetCode13': '13940',
#  'gi5DigitStreetCode14': '13940',
#  'gi5DigitStreetCode15': '13940',
#  'gi5DigitStreetCode16': '13940',
#  'gi5DigitStreetCode17': '13940',
#  'gi5DigitStreetCode18': '13940',
#  'gi5DigitStreetCode19': '45601',
#  'gi5DigitStreetCode2': '21230',
#  'gi5DigitStreetCode20': '45601',
#  'gi5DigitStreetCode21': '21790',
#  'gi5DigitStreetCode3': '45601',
#  'gi5DigitStreetCode4': '21790',
#  'gi5DigitStreetCode5': '45601',
#  'gi5DigitStreetCode6': '15350',
#  'gi5DigitStreetCode7': '45601',
#  'gi5DigitStreetCode8': '21790',
#  'gi5DigitStreetCode9': '45601',
#  'giBoroughCode1': '1',
#  'giBoroughCode10': '1',
#  'giBoroughCode11': '1',
#  'giBoroughCode12': '1',
#  'giBoroughCode13': '1',
#  'giBoroughCode14': '1',
#  'giBoroughCode15': '1',
#  'giBoroughCode16': '1',
#  'giBoroughCode17': '1',
#  'giBoroughCode18': '1',
#  'giBoroughCode19': '1',
#  'giBoroughCode2': '1',
#  'giBoroughCode20': '1',
#  'giBoroughCode21': '1',
#  'giBoroughCode3': '1',
#  'giBoroughCode4': '1',
#  'giBoroughCode5': '1',
#  'giBoroughCode6': '1',
#  'giBoroughCode7': '1',
#  'giBoroughCode8': '1',
#  'giBoroughCode9': '1',
#  'giBuildingIdentificationNumber1': '1088469',
#  'giBuildingIdentificationNumber10': '1088797',
#  'giBuildingIdentificationNumber11': '1088797',
#  'giBuildingIdentificationNumber12': '1088798',
#  'giBuildingIdentificationNumber13': '1088798',
#  'giBuildingIdentificationNumber14': '1088798',
#  'giBuildingIdentificationNumber15': '1088799',
#  'giBuildingIdentificationNumber16': '1088800',
#  'giBuildingIdentificationNumber17': '1088802',
#  'giBuildingIdentificationNumber18': '1088803',
#  'giBuildingIdentificationNumber19': '1089308',
#  'giBuildingIdentificationNumber2': '1088469',
#  'giBuildingIdentificationNumber20': '1089308',
#  'giBuildingIdentificationNumber21': '1089309',
#  'giBuildingIdentificationNumber3': '1088469',
#  'giBuildingIdentificationNumber4': '1088795',
#  'giBuildingIdentificationNumber5': '1088795',
#  'giBuildingIdentificationNumber6': '1088795',
#  'giBuildingIdentificationNumber7': '1088795',
#  'giBuildingIdentificationNumber8': '1088797',
#  'giBuildingIdentificationNumber9': '1088797',
#  'giDcpPreferredLgc1': '02',
#  'giDcpPreferredLgc10': '01',
#  'giDcpPreferredLgc11': '04',
#  'giDcpPreferredLgc12': '01',
#  'giDcpPreferredLgc13': '01',
#  'giDcpPreferredLgc14': '02',
#  'giDcpPreferredLgc15': '04',
#  'giDcpPreferredLgc16': '05',
#  'giDcpPreferredLgc17': '07',
#  'giDcpPreferredLgc18': '08',
#  'giDcpPreferredLgc19': '01',
#  'giDcpPreferredLgc2': '01',
#  'giDcpPreferredLgc20': '03',
#  'giDcpPreferredLgc21': '01',
#  'giDcpPreferredLgc3': '01',
#  'giDcpPreferredLgc4': '01',
#  'giDcpPreferredLgc5': '01',
#  'giDcpPreferredLgc6': '01',
#  'giDcpPreferredLgc7': '05',
#  'giDcpPreferredLgc8': '01',
#  'giDcpPreferredLgc9': '01',
#  'giGeographicIdentifier1': 'X',
#  'giGeographicIdentifier10': 'W',
#  'giGeographicIdentifier11': 'X',
#  'giGeographicIdentifier13': 'G',
#  'giGeographicIdentifier14': 'X',
#  'giGeographicIdentifier15': 'X',
#  'giGeographicIdentifier16': 'X',
#  'giGeographicIdentifier17': 'X',
#  'giGeographicIdentifier18': 'X',
#  'giGeographicIdentifier20': 'X',
#  'giGeographicIdentifier6': 'W',
#  'giGeographicIdentifier7': 'X',
#  'giHighHouseNumber12': '180',
#  'giHighHouseNumber19': '2',
#  'giHighHouseNumber2': '285',
#  'giHighHouseNumber21': '185',
#  'giHighHouseNumber3': '1',
#  'giHighHouseNumber4': '150',
#  'giHighHouseNumber5': '4',
#  'giHighHouseNumber8': '175',
#  'giHighHouseNumber9': '3',
#  'giLowHouseNumber12': '180',
#  'giLowHouseNumber19': '2',
#  'giLowHouseNumber2': '285',
#  'giLowHouseNumber21': '185',
#  'giLowHouseNumber3': '1',
#  'giLowHouseNumber4': '150',
#  'giLowHouseNumber5': '4',
#  'giLowHouseNumber8': '175',
#  'giLowHouseNumber9': '3',
#  'giSideOfStreetIndicator1': 'L',
#  'giSideOfStreetIndicator11': 'L',
#  'giSideOfStreetIndicator12': 'L',
#  'giSideOfStreetIndicator13': 'R',
#  'giSideOfStreetIndicator14': 'R',
#  'giSideOfStreetIndicator15': 'R',
#  'giSideOfStreetIndicator16': 'R',
#  'giSideOfStreetIndicator17': 'R',
#  'giSideOfStreetIndicator18': 'R',
#  'giSideOfStreetIndicator19': 'L',
#  'giSideOfStreetIndicator2': 'L',
#  'giSideOfStreetIndicator20': 'L',
#  'giSideOfStreetIndicator21': 'R',
#  'giSideOfStreetIndicator3': 'L',
#  'giSideOfStreetIndicator4': 'L',
#  'giSideOfStreetIndicator5': 'L',
#  'giSideOfStreetIndicator7': 'L',
#  'giSideOfStreetIndicator8': 'R',
#  'giSideOfStreetIndicator9': 'L',
#  'giStreetCode1': '14560102',
#  'giStreetCode10': '11535001',
#  'giStreetCode11': '14560104',
#  'giStreetCode12': '12179001',
#  'giStreetCode13': '11394001',
#  'giStreetCode14': '11394002',
#  'giStreetCode15': '11394004',
#  'giStreetCode16': '11394005',
#  'giStreetCode17': '11394007',
#  'giStreetCode18': '11394008',
#  'giStreetCode19': '14560101',
#  'giStreetCode2': '12123001',
#  'giStreetCode20': '14560103',
#  'giStreetCode21': '12179001',
#  'giStreetCode3': '14560101',
#  'giStreetCode4': '12179001',
#  'giStreetCode5': '14560101',
#  'giStreetCode6': '11535001',
#  'giStreetCode7': '14560105',
#  'giStreetCode8': '12179001',
#  'giStreetCode9': '14560101',
#  'giStreetName1': 'ONE WORLD TRADE CENTER',
#  'giStreetName10': 'CHURCH STREET',
#  'giStreetName11': 'THREE WORLD TRADE CENTER',
#  'giStreetName12': 'GREENWICH STREET',
#  'giStreetName13': 'NATIONAL 9/11 MEMORIAL',
#  'giStreetName14': 'NATIONAL 9/11 MUSEUM',
#  'giStreetName15': 'SOUTH MEMORIAL REFLECTING POOL',
#  'giStreetName16': 'NORTH MEMORIAL REFLECTING POOL',
#  'giStreetName17': '9/11 MEMORIAL WEST VENT NORTH',
#  'giStreetName18': '9/11 MEMORIAL WEST VENT SOUTH',
#  'giStreetName19': 'WORLD TRADE CENTER',
#  'giStreetName2': 'FULTON STREET',
#  'giStreetName20': 'TWO WORLD TRADE CENTER',
#  'giStreetName21': 'GREENWICH STREET',
#  'giStreetName3': 'WORLD TRADE CENTER',
#  'giStreetName4': 'GREENWICH STREET',
#  'giStreetName5': 'WORLD TRADE CENTER',
#  'giStreetName6': 'CHURCH STREET',
#  'giStreetName7': 'FOUR WORLD TRADE CENTER',
#  'giStreetName8': 'GREENWICH STREET',
#  'giStreetName9': 'WORLD TRADE CENTER',
#  'healthArea': '7700',
#  'healthCenterDistrict': '15',
#  'highBblOfThisBuildingsCondominiumUnits': '1000580001',
#  'highCrossStreetB5SC1': '111115',
#  'highCrossStreetCode1': '11111504',
#  'highCrossStreetName1': 'WEST STREET',
#  'highHouseNumberOfBlockfaceSortFormat': '000000000AA',
#  'hurricaneEvacuationZone': '1',
#  'individualSegmentLength': '00173',
#  'instructionalRegion': 'MS',
#  'interimAssistanceEligibilityIndicator': 'I',
#  'internalLabelXCoordinate': '0980828',
#  'internalLabelYCoordinate': '0198546',
#  'irregularlyShapedLotFlag': 'I',
#  'latitude': 40.713099086327894,
#  'latitudeInternalLabel': 40.71163895221414,
#  'legacySegmentId': '0162334',
#  'lionBoroughCode': '1',
#  'lionBoroughCodeForVanityAddress': '1',
#  'lionFaceCode': '4550',
#  'lionFaceCodeForVanityAddress': '4550',
#  'lionKey': '1455000040',
#  'lionKeyForVanityAddress': '1455000040',
#  'lionSequenceNumber': '00040',
#  'lionSequenceNumberForVanityAddress': '00040',
#  'listOf4Lgcs': '02',
#  'listOfGeographicIdentifiersOverflowFlag': 'E',
#  'longitude': -74.01306152916293,
#  'longitudeInternalLabel': -74.01234343376866,
#  'lowBblOfThisBuildingsCondominiumUnits': '1000580001',
#  'lowCrossStreetB5SC1': '133390',
#  'lowCrossStreetCode1': '13339001',
#  'lowCrossStreetName1': 'WASHINGTON STREET',
#  'lowHouseNumberOfBlockfaceSortFormat': '000000000AA',
#  'lowHouseNumberOfDefiningAddressRange': '000002000AA',
#  'message': '1 VESEY STREET IS THE UNDERLYING ADDRESS OF ONE WORLD TRADE CENTER',
#  'message2': 'LOT HAS MORE ITEMS THAN LISTED',
#  'noCrossStreetCalculationFlag': 'Y',
#  'nta': 'MN25',
#  'ntaName': 'Battery Park City-Lower Manhattan',
#  'numberOfCrossStreetB5SCsHighAddressEnd': '1',
#  'numberOfCrossStreetB5SCsLowAddressEnd': '1',
#  'numberOfCrossStreetsHighAddressEnd': '1',
#  'numberOfCrossStreetsLowAddressEnd': '1',
#  'numberOfEntriesInListOfGeographicIdentifiers': '0021',
#  'numberOfExistingStructuresOnLot': '0011',
#  'numberOfStreetFrontagesOfLot': '08',
#  'physicalId': '0146687',
#  'policePatrolBoroughCommand': '1',
#  'policePrecinct': '001',
#  'reasonCode': 'V',
#  'reasonCode1a': 'A',
#  'reasonCode1e': 'V',
#  'reasonCode2': 'A',
#  'returnCode1a': '01',
#  'returnCode1e': '01',
#  'roadwayType': '1',
#  'rpadBuildingClassificationCode': 'O4',
#  'rpadSelfCheckCodeForBbl': '6',
#  'sanbornBoroughCode': '1',
#  'sanbornPageNumber': '038',
#  'sanbornVolumeNumber': '01',
#  'sanbornVolumeNumberSuffix': 'S',
#  'sanitationCollectionSchedulingSectionAndSubsection': '1A',
#  'sanitationDistrict': '101',
#  'sanitationRecyclingCollectionSchedule': 'EF',
#  'sanitationRegularCollectionSchedule': 'MWF',
#  'sanitationSnowPriorityCode': 'P',
#  'segmentAzimuth': '149',
#  'segmentIdentifier': '0259549',
#  'segmentLengthInFeet': '00173',
#  'segmentOrientation': 'W',
#  'segmentTypeCode': 'U',
#  'sideOfStreetIndicator': 'L',
#  'sideOfStreetOfVanityAddress': 'L',
#  'specialAddressGeneratedRecordFlag': 'X',
#  'splitLowHouseNumber': '000002000AA',
#  'stateSenatorialDistrict': '26',
#  'streetName1In': 'ONE WORLD TRADE CENTER',
#  'streetStatus': '2',
#  'taxMapNumberSectionAndVolume': '10102',
#  'toLionNodeId': '0015199',
#  'toPreferredLgcsFirstSetOf5': '04',
#  'trafficDirection': 'P',
#  'underlyingHnsOnTrueStreet': '000001000AA',
#  'underlyingStreetCode': '13270001',
#  'uspsPreferredCityName': 'NEW YORK',
#  'workAreaFormatIndicatorIn': 'C',
#  'xCoordinate': '0980629',
#  'xCoordinateHighAddressEnd': '0980437',
#  'xCoordinateLowAddressEnd': '0980772',
#  'xCoordinateOfCenterofCurvature': '0000000',
#  'yCoordinate': '0199078',
#  'yCoordinateHighAddressEnd': '0199294',
#  'yCoordinateLowAddressEnd': '0199103',
#  'yCoordinateOfCenterofCurvature': '0000000',
#  'zipCode': '10007'}
